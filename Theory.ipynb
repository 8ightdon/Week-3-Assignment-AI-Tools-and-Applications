# %% [markdown]
# 1. Explain the primary differences between TensorFlow and PyTorch. When would you choose one over the other?

# %% [markdown]
# *Pytorch* is best research and fast iteration because to its dynamic nature and ease of use while *TensorFlow*, due to its robust ecosystem and established tools its mainly used for large scale production systems and deployment.
# When to choose:
# 1. TensorFlow.
# When ;
# a. *Targeting Production Deployment*
# b. *Built-in tools are required for monitoring or pipeline management*
# c. *A high-level interface is required for faster proto typing*
# d. *Working in an enterprie focused on large-scale solutions*
#
# 2. pyTorch
# When;
# a. *Researching, Experimenting or prototyping*
# b. *Building custom models with alot of control and flexibility*
